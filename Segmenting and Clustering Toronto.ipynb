# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=890001695')
soup = BeautifulSoup(res.content,'lxml')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table))[0]
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
#Here we're going to remove all of the "Not Assigned" Boroughs
df1 = df[df.Borough!='Not assigned']
df1.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights

# %%
df1['Neighbourhood'].value_counts()
# Out:
# St. James Town                                       2
# Runnymede                                            2
# Silver Hills                                         1
# Silverthorn                                          1
# Christie                                             1
# CFB Toronto                                          1
# Dorset Park                                          1
# South Niagara                                        1
# Underground city                                     1
# Thorncliffe Park                                     1
# King                                                 1
# Malvern                                              1
# Mount Olive                                          1
# Agincourt                                            1
# Forest Hill SE                                       1
# Davisville North                                     1
# Swansea                                              1
# ...

# %%
#Since there is only one "Not Assigned" Neighborhood we're going to assign that neighborhood the same name as the borough
df1.loc[[8], ['Neighbourhood']] = "Queen's Park"
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
df1.loc[8, 'Neighbourhood']
# Out:
# "Queen's Park"

# %%
df1 = df1.reset_index()

# %% [markdown]
# # Final DF For Part 1 Of Assignment

# %%
df_final = df1.drop(['index'], axis = 1)
df_final = df_final.rename(columns={'Postcode': 'Postal Code','Neighbourhood':'Neighborhood'})
df_final.head()
# Out:
#   Postal Code           Borough      Neighborhood
# 0         M3A        North York         Parkwoods
# 1         M4A        North York  Victoria Village
# 2         M5A  Downtown Toronto      Harbourfront
# 3         M5A  Downtown Toronto       Regent Park
# 4         M6A        North York  Lawrence Heights

# %%
df_final.shape
# Out:
# (211, 3)

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# # Merged DF For Part 2 Of Assignment

# %%
merged_df = pd.merge(left=df_final, right=df_data_1)
merged_df.head()
# Out:
#   Postal Code           Borough      Neighborhood   Latitude  Longitude
# 0         M3A        North York         Parkwoods  43.753259 -79.329656
# 1         M4A        North York  Victoria Village  43.725882 -79.315572
# 2         M5A  Downtown Toronto      Harbourfront  43.654260 -79.360636
# 3         M5A  Downtown Toronto       Regent Park  43.654260 -79.360636
# 4         M6A        North York  Lawrence Heights  43.718518 -79.464763

# %%
merged_df['Borough'].value_counts()
# Out:
# Etobicoke           45
# North York          38
# Scarborough         37
# Downtown Toronto    37
# Central Toronto     17
# West Toronto        13
# York                 9
# East Toronto         7
# East York            6
# Mississauga          1
# Queen's Park         1
# Name: Borough, dtype: int64

# %% [markdown]
# Because there were so many different neighborhoods in Downtown Toronto, I decided to just focus on that area.

# %%
toronto_df = merged_df[merged_df['Borough'] =='Downtown Toronto'].reset_index(drop=True)
toronto_df
# Out:
#    Postal Code           Borough                     Neighborhood   Latitude  \
# 0          M5A  Downtown Toronto                     Harbourfront  43.654260
# 1          M5A  Downtown Toronto                      Regent Park  43.654260
# 2          M5B  Downtown Toronto                          Ryerson  43.657162
# 3          M5B  Downtown Toronto                  Garden District  43.657162
# 4          M5C  Downtown Toronto                   St. James Town  43.651494
# 5          M5E  Downtown Toronto                      Berczy Park  43.644771
# 6          M5G  Downtown Toronto               Central Bay Street  43.657952
# 7          M6G  Downtown Toronto                         Christie  43.669542
# 8          M5H  Downtown Toronto                         Adelaide  43.650571
# 9          M5H  Downtown Toronto                             King  43.650571
# 10         M5H  Downtown Toronto                         Richmond  43.650571
# ...

# %%
import json # library to handle JSON files

# !conda install -c conda-forge --no-deps altair --yes

# !conda install -c conda-forge --no-deps vincent --yes


# !conda install -c conda-forge geopy=1.19.0 --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values


from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - altair
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#
# The following NEW packages will be INSTALLED:
#
#     altair: 4.1.0-py_1 conda-forge
#
#
# ...
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - vincent
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
# ...

# %%
# !conda install -c conda-forge branca
# !conda install -c conda-forge --no-deps folium=0.5.0 --yes
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - branca
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#
# The following NEW packages will be INSTALLED:
#
#     branca: 0.4.1-py_0 conda-forge
#
#
# ...
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
# ...

# %% [markdown]
# # Data Analysis, Maps, Clusters For Part 3 Of Assignment

# %%
address = 'Downtown Toronto, Ontario, Canada'

geolocator = Nominatim(user_agent="TO_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto are 43.6563221, -79.3809161.

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(toronto_df['Latitude'], toronto_df['Longitude'], toronto_df['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'JQA3V4LZQW1I5VR2EUJJBN4DKFPM3D0DNFXM3XQRTX4S2D2E' # your Foursquare ID
CLIENT_SECRET = 'UOZ2BKFMZ50BYX0CGZHGD4LANNB2MKBL3U51JHOGJT1GQELL' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 50
radius = 500

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: JQA3V4LZQW1I5VR2EUJJBN4DKFPM3D0DNFXM3XQRTX4S2D2E
# CLIENT_SECRET:UOZ2BKFMZ50BYX0CGZHGD4LANNB2MKBL3U51JHOGJT1GQELL

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=toronto_df['Neighborhood'],
                                   latitudes=toronto_df['Latitude'],
                                   longitudes=toronto_df['Longitude']
                                  )
# Out:
# Harbourfront
# Regent Park
# Ryerson
# Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Christie
# Adelaide
# King
# Richmond
# Harbourfront East
# Toronto Islands
# Union Station
# Design Exchange
# Toronto Dominion Centre
# Commerce Court
# Victoria Hotel
# Harbord
# University of Toronto
# Chinatown
# Grange Park
# Kensington Market
# CN Tower
# Bathurst Quay
# Island airport
# Harbourfront West
# King and Spadina
# Railway Lands
# South Niagara
# Rosedale
# Stn A PO Boxes 25 The Esplanade
# Cabbagetown
# St. James Town
# First Canadian Place
# Underground city
# Church and Wellesley

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (1481, 7)
#    Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Harbourfront               43.65426              -79.360636
# 1  Harbourfront               43.65426              -79.360636
# 2  Harbourfront               43.65426              -79.360636
# 3  Harbourfront               43.65426              -79.360636
# 4  Harbourfront               43.65426              -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0        Roselle Desserts       43.653447       -79.362017
# 1           Tandem Coffee       43.653559       -79.361809
# 2  Cooper Koo Family YMCA       43.653249       -79.358008
# 3     Body Blitz Spa East       43.654735       -79.359874
# 4         Corktown Common       43.655618       -79.356211
#
#         Venue Category
# 0               Bakery
# 1          Coffee Shop
# 2  Distribution Center
# 3                  Spa
# 4                 Park

# %%
#Looking at the number of Venues in each neighborhood
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                  Neighborhood Latitude  \
# Neighborhood
# Adelaide                                            50
# Bathurst Quay                                       16
# Berczy Park                                         50
# CN Tower                                            16
# Cabbagetown                                         45
# Central Bay Street                                  50
# Chinatown                                           50
# Christie                                            17
# Church and Wellesley                                50
# Commerce Court                                      50
# Design Exchange                                     50
# First Canadian Place                                50
# Garden District                                     50
# Grange Park                                         50
# Harbord                                             35
# Harbourfront                                        44
# ...

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 



col = toronto_onehot.pop("Neighborhood")
toronto_onehot.insert(0, col.name, col)


toronto_onehot.shape
# Out:
# (1481, 183)

# %%
#Grouping the dataframe by neighborhood to see the frequency of each type of venue
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()
toronto_grouped.head(10)
# Out:
#            Neighborhood  Airport  Airport Food Court  Airport Gate  \
# 0              Adelaide   0.0000              0.0000        0.0000
# 1         Bathurst Quay   0.0625              0.0625        0.0625
# 2           Berczy Park   0.0000              0.0000        0.0000
# 3              CN Tower   0.0625              0.0625        0.0625
# 4           Cabbagetown   0.0000              0.0000        0.0000
# 5    Central Bay Street   0.0000              0.0000        0.0000
# 6             Chinatown   0.0000              0.0000        0.0000
# 7              Christie   0.0000              0.0000        0.0000
# 8  Church and Wellesley   0.0000              0.0000        0.0000
# 9        Commerce Court   0.0000              0.0000        0.0000
#
#    Airport Lounge  Airport Service  Airport Terminal  American Restaurant  \
# 0           0.000           0.0000            0.0000                 0.04
# 1           0.125           0.1875            0.0625                 0.00
# ...

# %%
#Observing top 5 venues for each neighborhoood
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Adelaide----
#                  venue  freq
# 0          Coffee Shop  0.10
# 1                 Café  0.06
# 2           Restaurant  0.04
# 3         Concert Hall  0.04
# 4  American Restaurant  0.04
#
#
# ----Bathurst Quay----
#              venue  freq
# 0  Airport Service  0.19
# 1   Airport Lounge  0.12
# 2          Airport  0.06
# 3    Boat or Ferry  0.06
# 4  Harbor / Marina  0.06
#
#
# ----Berczy Park----
#                 venue  freq
# 0         Coffee Shop  0.08
# 1        Cocktail Bar  0.06
# 2            Beer Bar  0.04
# 3  Seafood Restaurant  0.04
# 4                Café  0.04
#
#
# ----CN Tower----
#              venue  freq
# 0  Airport Service  0.19
# 1   Airport Lounge  0.12
# 2          Airport  0.06
# 3    Boat or Ferry  0.06
# 4  Harbor / Marina  0.06
#
#
# ----Cabbagetown----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1         Pizza Place  0.07
# 2              Bakery  0.04
# 3  Italian Restaurant  0.04
# 4                Café  0.04
#
#
# ...

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
#Creating a dataframe with the 10 most common venues
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#     Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0       Adelaide           Coffee Shop                  Café
# 1  Bathurst Quay       Airport Service        Airport Lounge
# 2    Berczy Park           Coffee Shop          Cocktail Bar
# 3       CN Tower       Airport Service        Airport Lounge
# 4    Cabbagetown           Coffee Shop           Pizza Place
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0           Pizza Place          Concert Hall            Steakhouse
# 1               Airport       Harbor / Marina                 Plane
# 2                Bakery              Beer Bar           Cheese Shop
# 3               Airport       Harbor / Marina                 Plane
# 4                Market                  Café                Bakery
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0            Restaurant   American Restaurant                Bakery
# ...

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 2, 1, 2, 1, 1, 1, 3, 1, 0], dtype=int32)

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster_Labels', kmeans.labels_)

toronto_merged = toronto_df


toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head()
# Out:
#   Postal Code           Borough     Neighborhood   Latitude  Longitude  \
# 0         M5A  Downtown Toronto     Harbourfront  43.654260 -79.360636
# 1         M5A  Downtown Toronto      Regent Park  43.654260 -79.360636
# 2         M5B  Downtown Toronto          Ryerson  43.657162 -79.378937
# 3         M5B  Downtown Toronto  Garden District  43.657162 -79.378937
# 4         M5C  Downtown Toronto   St. James Town  43.651494 -79.375418
#
#    Cluster_Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               1           Coffee Shop                  Park
# 1               1           Coffee Shop                  Park
# 2               1                  Café        Clothing Store
# 3               1                  Café        Clothing Store
# 4               1           Coffee Shop                  Café
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                   Pub                Bakery        Breakfast Spot
# ...

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster_Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Looking at the map and dataframes of the different clusters of Downtown Toronto you notice the two central clusters (purple and red on the map) have very similar venues.  The main difference between the two is that Cluster 0 is made up of general cafés, coffee shops, bars and restaurants, and in Cluster 1 you can see neighborhoods with more specific types of venues such as Bakeries, Italian restaurants, Vietnamese restaurants, Parks, Aquariums and Chinese restaurants.

# %%
toronto_merged.loc[toronto_merged['Cluster_Labels'] == 0, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                Neighborhood  Cluster_Labels 1st Most Common Venue  \
# 14          Design Exchange               0                  Café
# 15  Toronto Dominion Centre               0                  Café
# 16           Commerce Court               0                 Hotel
# 17           Victoria Hotel               0                 Hotel
# 18                  Harbord               0                  Café
# 19    University of Toronto               0                  Café
# 34     First Canadian Place               0                  Café
# 35         Underground city               0                  Café
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 14           Coffee Shop    Seafood Restaurant                 Hotel
# 15           Coffee Shop    Seafood Restaurant                 Hotel
# 16                  Café           Coffee Shop                   Gym
# 17                  Café           Coffee Shop                   Gym
# ...

# %%
toronto_merged.loc[toronto_merged['Cluster_Labels'] == 1, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                        Neighborhood  Cluster_Labels 1st Most Common Venue  \
# 0                      Harbourfront               1           Coffee Shop
# 1                       Regent Park               1           Coffee Shop
# 2                           Ryerson               1                  Café
# 3                   Garden District               1                  Café
# 4                    St. James Town               1           Coffee Shop
# 5                       Berczy Park               1           Coffee Shop
# 6                Central Bay Street               1           Coffee Shop
# 8                          Adelaide               1           Coffee Shop
# 9                              King               1           Coffee Shop
# 10                         Richmond               1           Coffee Shop
# 11                Harbourfront East               1           Coffee Shop
# 12                  Toronto Islands               1           Coffee Shop
# ...

# %%
toronto_merged.loc[toronto_merged['Cluster_Labels'] == 2, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#          Neighborhood  Cluster_Labels 1st Most Common Venue  \
# 23           CN Tower               2       Airport Service
# 24      Bathurst Quay               2       Airport Service
# 25     Island airport               2       Airport Service
# 26  Harbourfront West               2       Airport Service
# 27   King and Spadina               2       Airport Service
# 28      Railway Lands               2       Airport Service
# 29      South Niagara               2       Airport Service
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 23        Airport Lounge               Airport       Harbor / Marina
# 24        Airport Lounge               Airport       Harbor / Marina
# 25        Airport Lounge               Airport       Harbor / Marina
# 26        Airport Lounge               Airport       Harbor / Marina
# 27        Airport Lounge               Airport       Harbor / Marina
# ...

# %%
toronto_merged.loc[toronto_merged['Cluster_Labels'] == 3, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#   Neighborhood  Cluster_Labels 1st Most Common Venue 2nd Most Common Venue  \
# 7     Christie               3         Grocery Store                  Café
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 7                  Park           Candy Store           Coffee Shop
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 7    Italian Restaurant            Restaurant            Baby Store
#
#   9th Most Common Venue 10th Most Common Venue
# 7    Athletics & Sports                  Diner

# %%
toronto_merged.loc[toronto_merged['Cluster_Labels'] == 4, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#    Neighborhood  Cluster_Labels 1st Most Common Venue 2nd Most Common Venue  \
# 30     Rosedale               4                  Park            Playground
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 30                 Trail          Concert Hall                 Diner
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 30    Dim Sum Restaurant          Dessert Shop      Department Store
#
#    9th Most Common Venue 10th Most Common Venue
# 30         Deli / Bodega           Dance Studio
